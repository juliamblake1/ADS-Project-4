# %% [markdown]
# # Machine Learning Fairness Algorithms Evaluation

# %% [markdown]
# #### Fairness in Machine Learning
# The aim of a fairness algorithm is to avoid the outcome decisions are being made unfairly to certain groups or individuals.
# - Algorithms are made by humans and trained by data which may be biased
# - However, there are many definitions of fairness that cannot be optimized at the same time

# %% [markdown]
# #### Learning fair representations (LFR)
#
# #### Prejudice Remover Regularizer (PR)

# %% [markdown]
# ### Data Pre-processing

# %%
import csv
import pandas as pd

# %%
compas_scores = pd.read_csv("compas-scores.csv")
compas_scores.head()
# Out:
#    id              name    first       last compas_screening_date   sex  \
# 0   1  miguel hernandez   miguel  hernandez            2013-08-14  Male
# 1   2      michael ryan  michael       ryan            2014-12-31  Male
# 2   3       kevon dixon    kevon      dixon            2013-01-27  Male
# 3   4          ed philo       ed      philo            2013-04-14  Male
# 4   5       marcu brown    marcu      brown            2013-01-13  Male
#
#           dob  age          age_cat              race  ...  vr_offense_date  \
# 0  1947-04-18   69  Greater than 45             Other  ...              NaN
# 1  1985-02-06   31          25 - 45         Caucasian  ...              NaN
# 2  1982-01-22   34          25 - 45  African-American  ...       2013-07-05
# 3  1991-05-14   24     Less than 25  African-American  ...              NaN
# 4  1993-01-21   23     Less than 25  African-American  ...              NaN
#
#                 vr_charge_desc  v_type_of_assessment  v_decile_score  \
# 0                          NaN      Risk of Violence               1
# 1                          NaN      Risk of Violence               2
# 2  Felony Battery (Dom Strang)      Risk of Violence               1
# 3                          NaN      Risk of Violence               3
# 4                          NaN      Risk of Violence               6
#
#    v_score_text  v_screening_date  type_of_assessment decile_score.1  \
# 0           Low        2013-08-14  Risk of Recidivism              1
# 1           Low        2014-12-31  Risk of Recidivism              5
# 2           Low        2013-01-27  Risk of Recidivism              3
# 3           Low        2013-04-14  Risk of Recidivism              4
# 4        Medium        2013-01-13  Risk of Recidivism              8
#
#   score_text screening_date
# 0        Low     2013-08-14
# 1     Medium     2014-12-31
# 2        Low     2013-01-27
# 3        Low     2013-04-14
# 4       High     2013-01-13
#
# [5 rows x 47 columns]

# %%
compas_scores_race = compas_scores.loc[compas_scores['race'].isin(['Caucasian' ,'African-American'])]
compas_scores_race
# Out:
#           id               name    first          last compas_screening_date  \
# 1          2       michael ryan  michael          ryan            2014-12-31
# 2          3        kevon dixon    kevon         dixon            2013-01-27
# 3          4           ed philo       ed         philo            2013-04-14
# 4          5        marcu brown    marcu         brown            2013-01-13
# 7          8      edward riddle   edward        riddle            2014-02-19
# ...      ...                ...      ...           ...                   ...
# 11748  11749  cody allencoveyou     cody  allencoveyou            2014-03-31
# 11749  11750     michael walker  michael        walker            2014-03-20
# 11751  11752   rodrick phillips  rodrick      phillips            2013-02-27
# 11753  11754  raymond hernandez  raymond     hernandez            2013-05-17
# 11755  11756   scott lomagistro    scott    lomagistro            2013-12-03
#
#         sex         dob  age          age_cat              race  ...  \
# 1      Male  1985-02-06   31          25 - 45         Caucasian  ...
# 2      Male  1982-01-22   34          25 - 45  African-American  ...
# 3      Male  1991-05-14   24     Less than 25  African-American  ...
# 4      Male  1993-01-21   23     Less than 25  African-American  ...
# 7      Male  1974-07-23   41          25 - 45         Caucasian  ...
# ...     ...         ...  ...              ...               ...  ...
# 11748  Male  1993-02-03   23     Less than 25         Caucasian  ...
# 11749  Male  1959-09-22   56  Greater than 45  African-American  ...
# 11751  Male  1953-02-24   63  Greater than 45  African-American  ...
# 11753  Male  1993-06-24   22     Less than 25         Caucasian  ...
# 11755  Male  1986-12-04   29          25 - 45         Caucasian  ...
#
#        vr_offense_date               vr_charge_desc  v_type_of_assessment  \
# 1                  NaN                          NaN      Risk of Violence
# 2           2013-07-05  Felony Battery (Dom Strang)      Risk of Violence
# 3                  NaN                          NaN      Risk of Violence
# 4                  NaN                          NaN      Risk of Violence
# 7                  NaN                          NaN      Risk of Violence
# ...                ...                          ...                   ...
# 11748              NaN                          NaN      Risk of Violence
# 11749              NaN                          NaN      Risk of Violence
# 11751              NaN                          NaN      Risk of Violence
# 11753              NaN                          NaN      Risk of Violence
# 11755              NaN                          NaN      Risk of Violence
#
#        v_decile_score  v_score_text  v_screening_date  type_of_assessment  \
# 1                   2           Low        2014-12-31  Risk of Recidivism
# 2                   1           Low        2013-01-27  Risk of Recidivism
# 3                   3           Low        2013-04-14  Risk of Recidivism
# 4                   6        Medium        2013-01-13  Risk of Recidivism
# 7                   2           Low        2014-02-19  Risk of Recidivism
# ...               ...           ...               ...                 ...
# 11748               5        Medium        2014-03-31  Risk of Recidivism
# 11749               1           Low        2014-03-20  Risk of Recidivism
# 11751               1           Low        2013-02-27  Risk of Recidivism
# 11753               5        Medium        2013-05-17  Risk of Recidivism
# 11755               2           Low        2013-12-03  Risk of Recidivism
#
#       decile_score.1 score_text screening_date
# 1                  5     Medium     2014-12-31
# 2                  3        Low     2013-01-27
# 3                  4        Low     2013-04-14
# 4                  8       High     2013-01-13
# 7                  6     Medium     2014-02-19
# ...              ...        ...            ...
# 11748              7     Medium     2014-03-31
# 11749              1        Low     2014-03-20
# 11751              1        Low     2013-02-27
# 11753              7     Medium     2013-05-17
# 11755              3        Low     2013-12-03
#
# [9898 rows x 47 columns]

# %%
# converting to binary data
df_one = pd.get_dummies(compas_scores_race["race"])
# print(df_one)
 
# display result
df_two = pd.concat((df_one, compas_scores_race), axis=1)
df_two = df_two.drop(["race"], axis=1)
df_two = df_two.drop(["Caucasian"], axis=1)
new_df = df_two.rename(columns={"African-American": "race"})
new_df
# Out:
#        race     id               name    first          last  \
# 1         0      2       michael ryan  michael          ryan
# 2         1      3        kevon dixon    kevon         dixon
# 3         1      4           ed philo       ed         philo
# 4         1      5        marcu brown    marcu         brown
# 7         0      8      edward riddle   edward        riddle
# ...     ...    ...                ...      ...           ...
# 11748     0  11749  cody allencoveyou     cody  allencoveyou
# 11749     1  11750     michael walker  michael        walker
# 11751     1  11752   rodrick phillips  rodrick      phillips
# 11753     0  11754  raymond hernandez  raymond     hernandez
# 11755     0  11756   scott lomagistro    scott    lomagistro
#
#       compas_screening_date   sex         dob  age          age_cat  ...  \
# 1                2014-12-31  Male  1985-02-06   31          25 - 45  ...
# 2                2013-01-27  Male  1982-01-22   34          25 - 45  ...
# 3                2013-04-14  Male  1991-05-14   24     Less than 25  ...
# 4                2013-01-13  Male  1993-01-21   23     Less than 25  ...
# 7                2014-02-19  Male  1974-07-23   41          25 - 45  ...
# ...                     ...   ...         ...  ...              ...  ...
# 11748            2014-03-31  Male  1993-02-03   23     Less than 25  ...
# 11749            2014-03-20  Male  1959-09-22   56  Greater than 45  ...
# 11751            2013-02-27  Male  1953-02-24   63  Greater than 45  ...
# 11753            2013-05-17  Male  1993-06-24   22     Less than 25  ...
# 11755            2013-12-03  Male  1986-12-04   29          25 - 45  ...
#
#        vr_offense_date               vr_charge_desc  v_type_of_assessment  \
# 1                  NaN                          NaN      Risk of Violence
# 2           2013-07-05  Felony Battery (Dom Strang)      Risk of Violence
# 3                  NaN                          NaN      Risk of Violence
# 4                  NaN                          NaN      Risk of Violence
# 7                  NaN                          NaN      Risk of Violence
# ...                ...                          ...                   ...
# 11748              NaN                          NaN      Risk of Violence
# 11749              NaN                          NaN      Risk of Violence
# 11751              NaN                          NaN      Risk of Violence
# 11753              NaN                          NaN      Risk of Violence
# 11755              NaN                          NaN      Risk of Violence
#
#        v_decile_score  v_score_text  v_screening_date  type_of_assessment  \
# 1                   2           Low        2014-12-31  Risk of Recidivism
# 2                   1           Low        2013-01-27  Risk of Recidivism
# 3                   3           Low        2013-04-14  Risk of Recidivism
# 4                   6        Medium        2013-01-13  Risk of Recidivism
# 7                   2           Low        2014-02-19  Risk of Recidivism
# ...               ...           ...               ...                 ...
# 11748               5        Medium        2014-03-31  Risk of Recidivism
# 11749               1           Low        2014-03-20  Risk of Recidivism
# 11751               1           Low        2013-02-27  Risk of Recidivism
# 11753               5        Medium        2013-05-17  Risk of Recidivism
# 11755               2           Low        2013-12-03  Risk of Recidivism
#
#       decile_score.1 score_text screening_date
# 1                  5     Medium     2014-12-31
# 2                  3        Low     2013-01-27
# 3                  4        Low     2013-04-14
# 4                  8       High     2013-01-13
# 7                  6     Medium     2014-02-19
# ...              ...        ...            ...
# 11748              7     Medium     2014-03-31
# 11749              1        Low     2014-03-20
# 11751              1        Low     2013-02-27
# 11753              7     Medium     2013-05-17
# 11755              3        Low     2013-12-03
#
# [9898 rows x 47 columns]
